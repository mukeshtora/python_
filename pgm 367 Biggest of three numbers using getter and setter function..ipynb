# %%
"""
pg.no 367
16/12/23
Biggest of three numbers using getter and setter function.
"""
class big3():
    __a=None
    __b=None
    __c=None
    __r=None
    
    def __init__(self):
        self.__a=35
        self.__b=56
        self.__c=20
    def find(self):
        self.__r=(self.__a if self.__a>self.__c else self.__c) if self.__a>self.__b else (self.__b if self.__b>self.__c else self.__c)
    def disp(self):
        print(self.__r)
    def seta(self,a=100):
        self.__a=a
    def setb(self,a=200):
        self.__b=a
    def setc(self,a=300):
        self.__c=a
    def setabc(self,a=10,b=20,c=30):
        self.__a=a
        self.__b=b
        self.__c=c
    def setobj(self,obj):
        self.__a=obj.__a
        self.__b=obj.__b
        self.__c=obj.__c
    def reset(self):
        self.__a=35
        self.__b=56
        self.__c=20
    def geta(self):
        return(self.__a)
    def getb(self):
        return(self.__b)
    def getc(self):
        return(self.__c)
    def getabc(self):
        return(self.__a,self.__b,self.__c)
    def getobj(self,obj):
        return (self)
#main
a=big3()
a.find()
print("find 1")
a.disp()

a.seta()
a.setb()
a.setc()
a.find()
print("find 2")
a.disp()

a.setabc()
a.find()
print("find 3")
a.disp()

n=big3()
n.seta(3000)
n.setb(4000)
a.setobj(n)
a.find()
print("find 4")
a.disp()

a.reset()

b=a.geta()
print("find 5: ",b)
b=a.getb()
print("find 6: ",b)
b=a.getc()
print("find 7: ",b)
b=a.getabc()
print("find 8: ",b)

b=a.getobj(n)
b.setobj(n)
print("find 9: ",b.getabc())
# Out:
# find 1
# 56
# find 2
# 300
# find 3
# 30
# find 4
# 4000
# find 5:  35
# find 6:  56
# find 7:  20
# find 8:  (35, 56, 20)
# find 9:  (3000, 4000, 20)
